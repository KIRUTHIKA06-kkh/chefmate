# %%
import boto3
from dotenv import load_dotenv
import os

# %% [markdown]
# Downloading the raw files from the AWS S3 bucket

# %%
load_dotenv()
# Out:
# True

# %%
aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')
region_name = "ap-south-1"

# %%
s3_client = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# %%
buckets=s3_client.list_buckets()
buckets
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 buckets=s3_client.list_buckets()
#       2 buckets
#
# File /workspaces/chefmate/.venv/lib/python3.12/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File /workspaces/chefmate/.venv/lib/python3.12/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ClientError: An error occurred (InvalidAccessKeyId) when calling the ListBuckets operation: The AWS Access Key Id you provided does not exist in our records.

# %%
s3_client.download_file('chefmatebucket01','file1.json','file1.json')
s3_client.download_file('chefmatebucket01','file2.json','file2.json')
s3_client.download_file('chefmatebucket01','file3.json','file3.json')
s3_client.download_file('chefmatebucket01','file4.json','file4.json')
s3_client.download_file('chefmatebucket01','file5.json','file5.json')

# %% [markdown]
# Converting the JSON file to Structured Dataframe

# %%
import pandas as pd
import json
import warnings
warnings.filterwarnings("ignore")

# %%
zomato_file1  = pd.read_json("file1.json")
zomato_file2  = pd.read_json("file2.json")
zomato_file3  = pd.read_json("file3.json")
zomato_file4  = pd.read_json("file4.json")
zomato_file5  = pd.read_json("file5.json")

# %% [markdown]
# zomato_file1 dataframe

# %%
zomato_file1
# Out:
#      results_found                                        restaurants  \
# 0          17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1           4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2          13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3          10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4           7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 474            NaN                                                NaN
# 475            NaN                                                NaN
# 476            NaN                                                NaN
# 477            NaN                                                NaN
# 478            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# 0             20.0            1.0                 NaN    NaN    NaN
# 1             20.0            1.0                 NaN    NaN    NaN
# 2             20.0            1.0                 NaN    NaN    NaN
# 3             20.0            1.0                 NaN    NaN    NaN
# 4             20.0            1.0                 NaN    NaN    NaN
# ..             ...            ...                 ...    ...    ...
# 474            NaN            NaN  API limit exceeded  440.0
# 475            NaN            NaN  API limit exceeded  440.0
# 476            NaN            NaN  API limit exceeded  440.0
# 477            NaN            NaN  API limit exceeded  440.0
# 478            NaN            NaN  API limit exceeded  440.0
#
# [479 rows x 7 columns]

# %%
with open('file1.json', 'r') as file:
    data = json.load(file)

# %%
flattened_data1 = []
for i in range(len(data)):
  keys = data[i].keys()
  if 'restaurants' in keys:
    restaurants = data[i]['restaurants']  

    for item in restaurants:
        restaurant = item['restaurant']
        flattened_data1.append({
            "Restaurant ID": restaurant.get("R", {}).get("res_id"),
            "Restaurant Name": restaurant.get("name"),
            "Location": restaurant["location"].get("address"),
            "Cuisine": restaurant.get("cuisines"),
            "Ratings": restaurant["user_rating"].get("aggregate_rating"),
            "Rating text": restaurant["user_rating"].get("rating_text"),
            "Average Cost for Two": restaurant.get("average_cost_for_two"),
            "Price Range": restaurant.get("price_range"),
            "Table Booking": restaurant.get("has_table_booking"),
            "Online Delivery": restaurant.get("has_online_delivery"),
            "Delivering now": restaurant.get("is_delivering_now"),
            "Longitude": restaurant["location"].get("longitude"),
            "Latitude": restaurant["location"].get("latitude"),
            "City": restaurant["location"].get("city"),
            "Locality": restaurant["location"].get("locality")
})

# %%
zomato_df1 = pd.DataFrame(flattened_data1)
zomato_df1
# Out:
#       Restaurant ID             Restaurant Name  \
# 0            308322            Hauz Khas Social
# 1          18037817  Qubitos - The Terrace Cafe
# 2            312345             The Hudson Cafe
# 3            307490           Summer House Cafe
# 4          18241537                 38 Barracks
# ...             ...                         ...
# 1175        7602340               The Boozy Cow
# 1176        7600217                 La Favorita
# 1177        7601577           Roseleaf Bar Cafe
# 1178        7602224                   Civerinos
# 1179        7600118             The Hanging Bat
#
#                                                Location  \
# 0                9-A & 12, Hauz Khas Village, New Delhi
# 1     C-7, Vishal Enclave, Opposite Metro Pillar 417...
# 2     2524, 1st Floor, Hudson Lane, Delhi University...
# 3     1st Floor, DDA Shopping Complex, Aurobindo Pla...
# 4        M-38, Outer Circle, Connaught Place, New Delhi
# ...                                                 ...
# 1175   17 Frederick Street, New Town, Edinburgh EH2 2EY
# 1176       325-331 Leith Walk, Leith, Edinburgh EH6 8SA
# 1177     23-24 Sandport Place, Leith, Edinburgh EH6 6EW
# 1178  5 Hunter Square, Royal Mile, Old Town, Edinbur...
# 1179      133 Lothian Road, Old Town, Edinburgh EH3 9AD
#
#                                                 Cuisine Ratings Rating text  \
# 0            Continental, American, Asian, North Indian     4.3   Very Good
# 1     Thai, European, Mexican, North Indian, Chinese...     4.5   Excellent
# 2                   Cafe, Italian, Continental, Chinese     4.4   Very Good
# 3                                  Italian, Continental     4.1   Very Good
# 4                North Indian, Italian, Asian, American     4.4   Very Good
# ...                                                 ...     ...         ...
# 1175                                      Burger, Grill     4.0   Very Good
# 1176                                            Italian     4.5   Excellent
# 1177                                     Scottish, Cafe     4.7   Excellent
# 1178                                     Pizza, Italian     3.7        Good
# 1179                                           American     3.5        Good
#
#       Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                     1600            3              1                1
# 1                     1500            3              1                0
# 2                      850            2              0                1
# 3                     1850            3              1                0
# 4                     1600            3              1                0
# ...                    ...          ...            ...              ...
# 1175                    40            3              0                0
# 1176                    30            3              0                0
# 1177                    45            3              0                0
# 1178                    35            3              0                0
# 1179                    35            3              0                0
#
#       Delivering now      Longitude       Latitude       City  \
# 0                  0  77.1944706000  28.5542851000  New Delhi
# 1                  0  77.1177015000  28.6471325000  New Delhi
# 2                  0  77.2043172000  28.6949468000  New Delhi
# 3                  0  77.2038090000  28.5525204000  New Delhi
# 4                  0  77.2228584811  28.6330248887  New Delhi
# ...              ...            ...            ...        ...
# 1175               0  -3.1995690000  55.9519740000  Edinburgh
# 1176               0  -3.1768583333  55.9646694444  Edinburgh
# 1177               0  -3.1736790000  55.9766440000  Edinburgh
# 1178               0  -3.1879620000  55.9496370000  Edinburgh
# 1179               0  -3.2055222222  55.9456222222  Edinburgh
#
#                         Locality
# 0              Hauz Khas Village
# 1                 Rajouri Garden
# 2     Delhi University-GTB Nagar
# 3                      Hauz Khas
# 4                Connaught Place
# ...                          ...
# 1175                    New Town
# 1176                       Leith
# 1177                       Leith
# 1178                    Old Town
# 1179                    Old Town
#
# [1180 rows x 15 columns]

# %% [markdown]
# Zomato_file2 dataframe

# %%
zomato_file2
# Out:
#      results_found  results_start  results_shown  \
# 0          1263908             21             20
# 1          1263908             21             20
# 2          1263908             21             20
# 3          1263908             21             20
# 4          1263908             21             20
# ..             ...            ...            ...
# 545             32             21             11
# 546          17151             21             20
# 547             33             21             12
# 548          17151             21             20
# 549          17151             21             20
#
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# ..                                                 ...
# 545  [{'restaurant': {'R': {'res_id': 18433895}, 'a...
# 546  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 547  [{'restaurant': {'R': {'res_id': 309672}, 'api...
# 548  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 549  [{'restaurant': {'R': {'res_id': 313256}, 'api...
#
# [550 rows x 4 columns]

# %%
with open('file2.json', 'r') as file:
    data = json.load(file)

# %%
flattened_data2 = []
for i in range(len(data)):
  keys = data[i].keys()
  if 'restaurants' in keys:
    restaurants = data[i]['restaurants']  

    for item in restaurants:
        restaurant = item['restaurant']
        flattened_data2.append({
            "Restaurant ID": restaurant.get("R", {}).get("res_id"),
            "Restaurant Name": restaurant.get("name"),
            "Location": restaurant["location"].get("address"),
            "Cuisine": restaurant.get("cuisines"),
            "Ratings": restaurant["user_rating"].get("aggregate_rating"),
            "Rating text": restaurant["user_rating"].get("rating_text"),
            "Average Cost for Two": restaurant.get("average_cost_for_two"),
            "Price Range": restaurant.get("price_range"),
            "Table Booking": restaurant.get("has_table_booking"),
            "Online Delivery": restaurant.get("has_online_delivery"),
            "Delivering now": restaurant.get("is_delivering_now"),
            "Longitude": restaurant["location"].get("longitude"),
            "Latitude": restaurant["location"].get("latitude"),
            "City": restaurant["location"].get("city"),
            "Locality": restaurant["location"].get("locality")
})

# %%
zomato_df2 = pd.DataFrame(flattened_data2)
zomato_df2
# Out:
#        Restaurant ID          Restaurant Name  \
# 0           16668008            Arigato Sushi
# 1             801690                    Mocha
# 2           17558738          Blue House Cafe
# 3           16611701              Star Buffet
# 4            2100784  11th Avenue Cafe Bistro
# ...              ...                      ...
# 10597       18289242         Cyber Hub Social
# 10598            799                   Gulati
# 10599         301998             Punjab Grill
# 10600         307113                   Diggin
# 10601       18345728           Masala Library
#
#                                                 Location  \
# 0               14 Second Ave North, Yorkton, SK S3N 1G1
# 1      CP-1, 2nd Floor, Anand Plaza, Viram Khand-1, N...
# 2                      919 Bridge St, Vernonia, OR 97064
# 3                           58 Hanbury St, Mayfield, NSW
# 4      Opposite Assam State Museum, Dighalipukhuri, T...
# ...                                                  ...
# 10597                 Cyber Hub, DLF Cyber City, Gurgaon
# 10598                  6, Pandara Road Market, New Delhi
# 10599             Pacific Mall, Tagore Garden, New Delhi
# 10600  Anand Lok Shopping Centre, Opposite Gargi Coll...
# 10601                           21 A, Janpath, New Delhi
#
#                                           Cuisine Ratings Rating text  \
# 0                                           Asian     3.3     Average
# 1                      Cafe, Italian, Continental     4.6   Excellent
# 2                   Coffee and Tea, Mediterranean     4.3   Very Good
# 3                                           Asian     2.9     Average
# 4            Cafe, American, Italian, Continental     4.1   Very Good
# ...                                           ...     ...         ...
# 10597  Continental, American, Asian, North Indian     4.3   Very Good
# 10598                       North Indian, Mughlai     4.4   Very Good
# 10599                                North Indian     4.3   Very Good
# 10600                  Italian, Continental, Cafe     4.2   Very Good
# 10601                               Modern Indian     4.9   Excellent
#
#        Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                        25            2              0                0
# 1                       800            3              0                0
# 2                        10            1              0                0
# 3                        20            2              0                0
# 4                       400            2              0                0
# ...                     ...          ...            ...              ...
# 10597                  1500            3              1                1
# 10598                  1500            3              0                1
# 10599                  1600            3              1                1
# 10600                  1400            3              1                1
# 10601                  5000            4              0                0
#
#        Delivering now        Longitude        Latitude       City  \
# 0                   0  -102.4613173000   51.2106824000    Yorkton
# 1                   0    81.0011849000   26.8528099000    Lucknow
# 2                   0  -123.1954368000   45.8586670000   Vernonia
# 3                   0   151.7343832000  -32.8991780000   Mayfield
# 4                   0    91.7523143068   26.1860014826   Guwahati
# ...               ...              ...             ...        ...
# 10597               0    77.0885080000   28.4939356000    Gurgaon
# 10598               0    77.2297330000   28.6081402000  New Delhi
# 10599               0    77.1065034000   28.6422159000  New Delhi
# 10600               0    77.2194983000   28.5556355000  New Delhi
# 10601               0    77.2186451000   28.6182446000  New Delhi
#
#                         Locality
# 0                        Yorkton
# 1                    Gomti Nagar
# 2                       Vernonia
# 3                       Mayfield
# 4                    Uzan Bazaar
# ...                          ...
# 10597  Cyber Hub, DLF Cyber City
# 10598        Pandara Road Market
# 10599              Tagore Garden
# 10600                  Anand Lok
# 10601                    Janpath
#
# [10602 rows x 15 columns]

# %% [markdown]
# Zomato_file3 dataframe

# %%
zomato_file3
# Out:
#      results_found  results_start  results_shown  \
# 0        1263908.0           41.0           20.0
# 1        1263908.0           41.0           20.0
# 2        1263908.0           41.0           20.0
# 3        1263908.0           41.0           20.0
# 4        1263908.0           41.0           20.0
# ..             ...            ...            ...
# 545            NaN            NaN            NaN
# 546            NaN            NaN            NaN
# 547            NaN            NaN            NaN
# 548            NaN            NaN            NaN
# 549            NaN            NaN            NaN
#
#                                            restaurants   code status  \
# 0    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 1    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 2    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 3    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 4    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# ..                                                 ...    ...    ...
# 545                                                NaN  440.0
# 546                                                NaN  440.0
# 547                                                NaN  440.0
# 548                                                NaN  440.0
# 549                                                NaN  440.0
#
#                 message
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 545  API limit exceeded
# 546  API limit exceeded
# 547  API limit exceeded
# 548  API limit exceeded
# 549  API limit exceeded
#
# [550 rows x 7 columns]

# %%
with open('file3.json', 'r') as file:
    data = json.load(file)

# %%
flattened_data3 = []
for i in range(len(data)):
  keys = data[i].keys()
  if 'restaurants' in keys:
    restaurants = data[i]['restaurants']  

    for item in restaurants:
        restaurant = item['restaurant']
        flattened_data3.append({
            "Restaurant ID": restaurant.get("R", {}).get("res_id"),
            "Restaurant Name": restaurant.get("name"),
            "Location": restaurant["location"].get("address"),
            "Cuisine": restaurant.get("cuisines"),
            "Ratings": restaurant["user_rating"].get("aggregate_rating"),
            "Rating text": restaurant["user_rating"].get("rating_text"),
            "Average Cost for Two": restaurant.get("average_cost_for_two"),
            "Price Range": restaurant.get("price_range"),
            "Table Booking": restaurant.get("has_table_booking"),
            "Online Delivery": restaurant.get("has_online_delivery"),
            "Delivering now": restaurant.get("is_delivering_now"),
            "Longitude": restaurant["location"].get("longitude"),
            "Latitude": restaurant["location"].get("latitude"),
            "City": restaurant["location"].get("city"),
            "Locality": restaurant["location"].get("locality")
})

# %%
zomato_df3 = pd.DataFrame(flattened_data3)
zomato_df3
# Out:
#       Restaurant ID                       Restaurant Name  \
# 0           2100702                       Barbeque Nation
# 1          16608059                   1918 Bistro & Grill
# 2          17558684                Berry Patch Restaurant
# 3          16604896             La Trattoria of Lavandula
# 4          17536645  Jehova es Mi Pastor Tacos y Burritos
# ...             ...                                   ...
# 8681       16512333             Britto's Bar & Restaurant
# 8682       17559793             Fishpatrick's Crabby Cafe
# 8683       16607969                       Bespoke Harvest
# 8684       17842104                                   Mr.
# 8685       17687832         Vince's Restaurant & Pizzeria
#
#                                              Location  \
# 0      2nd Floor, Adityam Building, Ulubari, Guwahati
# 1                           94 Murray St, Tanunda, SA
# 2                     49289 Us-30, Westport, OR 97016
# 3     350 Hepburn-Newstead Road, Hepburn Springs, VIC
# 4               135 W. Main Street, Fernley, NV 89408
# ...                                               ...
# 8681                Baga Calangute, Bardez, Baga, Goa
# 8682      196 Bayfront Loop, Winchester Bay, OR 97467
# 8683                        16 Grant St, Forrest, VIC
# 8684                     23 Victoria St, Macedon, VIC
# 8685                    619 4th Ave, Monroe, WI 53566
#
#                                           Cuisine Ratings Rating text  \
# 0                                    North Indian     4.9   Excellent
# 1                   Modern Australian, Australian     4.4   Very Good
# 2                   American, Breakfast, Desserts     4.3   Very Good
# 3                           Italian, Fusion, Cafe     3.8        Good
# 4                                         Mexican     3.7        Good
# ...                                           ...     ...         ...
# 8681  North Indian, Continental, Chinese, Seafood     4.3   Very Good
# 8682                       Burger, Seafood, Steak     3.2     Average
# 8683                             Cafe, Australian     3.7        Good
# 8684                                         Cafe     3.5        Good
# 8685                               Italian, Pizza     3.6        Good
#
#       Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                     1500            4              0                0
# 1                       30            3              0                0
# 2                       10            1              0                0
# 3                        7            1              0                0
# 4                       10            1              0                0
# ...                    ...          ...            ...              ...
# 8681                  1400            4              0                0
# 8682                    25            2              0                0
# 8683                    20            2              0                0
# 8684                    20            2              0                0
# 8685                    25            2              0                0
#
#       Delivering now        Longitude        Latitude             City  \
# 0                  0    91.7598570000   26.1721190000         Guwahati
# 1                  0   138.9660640000  -34.5196190000          Tanunda
# 2                  0  -123.3681510000   46.1269670000       Clatskanie
# 3                  0   144.1100620000  -37.2754940000  Hepburn Springs
# 4                  0  -119.2526940000   39.6075150000          Fernley
# ...              ...              ...             ...              ...
# 8681               0    73.7494780582   15.5612954890              Goa
# 8682               0  -124.1753460000   43.6789980000   Winchester Bay
# 8683               0   143.7143150000  -38.5172920000          Forrest
# 8684               0   144.5641740000  -37.4231890000          Macedon
# 8685               0   -89.6534870000   42.6063060000           Monroe
#
#              Locality
# 0             Ulubari
# 1             Tanunda
# 2          Clatskanie
# 3     Hepburn Springs
# 4             Fernley
# ...               ...
# 8681             Baga
# 8682   Winchester Bay
# 8683          Forrest
# 8684          Macedon
# 8685           Monroe
#
# [8686 rows x 15 columns]

# %% [markdown]
# Zomato_file4 dataframe

# %%
zomato_file4
# Out:
#      results_found  results_start  results_shown  \
# 0          1263908             61             20
# 1          1263908             61             20
# 2          1263908             61             20
# 3          1263908             61             20
# 4          1263908             61             20
# ..             ...            ...            ...
# 474        1263908             61             20
# 475        1263908             61             20
# 476        1263908             61             20
# 477        1263908             61             20
# 478        1263908             61             20
#
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# ..                                                 ...
# 474  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 475  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 476  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 477  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 478  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
#
# [479 rows x 4 columns]

# %%
with open('file4.json', 'r') as file:
    data = json.load(file)

# %%
flattened_data4 = []
for i in range(len(data)):
  keys = data[i].keys()
  if 'restaurants' in keys:
    restaurants = data[i]['restaurants']  

    for item in restaurants:
        restaurant = item['restaurant']
        flattened_data4.append({
            "Restaurant ID": restaurant.get("R", {}).get("res_id"),
            "Restaurant Name": restaurant.get("name"),
            "Location": restaurant["location"].get("address"),
            "Cuisine": restaurant.get("cuisines"),
            "Ratings": restaurant["user_rating"].get("aggregate_rating"),
            "Rating text": restaurant["user_rating"].get("rating_text"),
            "Average Cost for Two": restaurant.get("average_cost_for_two"),
            "Price Range": restaurant.get("price_range"),
            "Table Booking": restaurant.get("has_table_booking"),
            "Online Delivery": restaurant.get("has_online_delivery"),
            "Delivering now": restaurant.get("is_delivering_now"),
            "Longitude": restaurant["location"].get("longitude"),
            "Latitude": restaurant["location"].get("latitude"),
            "City": restaurant["location"].get("city"),
            "Locality": restaurant["location"].get("locality")
})

# %%
zomato_df4 = pd.DataFrame(flattened_data4)
zomato_df4
# Out:
#       Restaurant ID           Restaurant Name  \
# 0          16604370            Mad Cowes Cafe
# 1          16643459        Consort Restaurant
# 2          18185059             Cafe Arabelle
# 3          18385186           The Cafe Baraco
# 4           2200000           Kesar Da Dhabha
# ...             ...                       ...
# 8860       17557488     Burger Queen Drive In
# 8861       18182702  Nonna's Pasta & Pizzeria
# 8862       16608864         Taste of Balingup
# 8863          13231                Le Plaisir
# 8864       16613649        Vivo Bar and Grill
#
#                                                Location  \
# 0                        4/17 The Esplanade, Cowes, VIC
# 1                 4931 50th Street, Consort, AB T0C 1B0
# 2     Ayala Mall, Solenad, Nuvali, Santa Rosa - Taga...
# 3     34, Shribhuvan Complex, Near Memnagar Fire Sta...
# 4     Near Telephone Exchange, Chowk Passian, Shastr...
# ...                                                 ...
# 8860                     109 S F St, Lakeview, OR 97630
# 8861  Ground Floor, Building G, Solenad 3, Nuvali, D...
# 8862                 63 South Western Hwy, Balingup, WA
# 8863  759/125, Rajkamal, Opposite Kelkar Eye Hospita...
# 8864              49 Williams Esplanade, Palm Cove, QLD
#
#                                            Cuisine Ratings Rating text  \
# 0     Breakfast, Coffee and Tea, Modern Australian     3.7        Good
# 1                                Chinese, Canadian     3.0     Average
# 2                Cafe, American, Italian, Filipino     3.6        Good
# 3                                    Cafe, Italian     4.4   Very Good
# 4                                     North Indian     4.1   Very Good
# ...                                            ...     ...         ...
# 8860                    Burger, Desserts, Sandwich     3.6        Good
# 8861                                Italian, Pizza     4.0   Very Good
# 8862                             Modern Australian     3.2     Average
# 8863                            European, Desserts     4.8   Excellent
# 8864                        Mediterranean, Seafood     4.4   Very Good
#
#       Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                       20            2              0                0
# 1                       25            2              0                0
# 2                      800            3              0                0
# 3                      600            2              0                1
# 4                      500            2              0                0
# ...                    ...          ...            ...              ...
# 8860                    10            1              0                0
# 8861                   850            3              0                0
# 8862                    20            2              0                0
# 8863                  1000            3              0                0
# 8864                    30            3              0                0
#
#       Delivering now        Longitude        Latitude            City  \
# 0                  0   145.2378130000  -38.4483070000  Phillip Island
# 1                  0  -110.7746994000   52.0082889000         Consort
# 2                  0   121.0570400000   14.2370820000      Santa Rosa
# 3                  0    72.5504755000   23.0443367000       Ahmedabad
# 4                  0    74.8730050000   31.6243860000        Amritsar
# ...              ...              ...             ...             ...
# 8860               0  -120.3458000000   42.1885000000        Lakeview
# 8861               0   121.0565873981   14.2376789732      Santa Rosa
# 8862               0   115.9844924000  -33.7845269000        Balingup
# 8863               0    73.8384293765   18.5142099831            Pune
# 8864               0   145.6707680000  -16.7480830000       Palm Cove
#
#                              Locality
# 0                      Phillip Island
# 1                             Consort
# 2        Nuvali, Don Jose, Santa Rosa
# 3                         Navrangpura
# 4                           Town Hall
# ...                               ...
# 8860                         Lakeview
# 8861  Solenad 3, Don Jose, Santa Rosa
# 8862                         Balingup
# 8863                  Deccan Gymkhana
# 8864                        Palm Cove
#
# [8865 rows x 15 columns]

# %% [markdown]
# Zomato_file5 dataframe

# %%
zomato_file5
# Out:
#      results_found                                        restaurants  \
# 0              0.0                                                 []
# 1           6835.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2              0.0                                                 []
# 3              0.0                                                 []
# 4           8680.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 295            NaN                                                NaN
# 296            NaN                                                NaN
# 297            NaN                                                NaN
# 298            NaN                                                NaN
# 299            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# 0              0.0            1.0                 NaN    NaN    NaN
# 1             20.0            1.0                 NaN    NaN    NaN
# 2              0.0            1.0                 NaN    NaN    NaN
# 3              0.0            1.0                 NaN    NaN    NaN
# 4             20.0            1.0                 NaN    NaN    NaN
# ..             ...            ...                 ...    ...    ...
# 295            NaN            NaN  API limit exceeded  440.0
# 296            NaN            NaN  API limit exceeded  440.0
# 297            NaN            NaN  API limit exceeded  440.0
# 298            NaN            NaN  API limit exceeded  440.0
# 299            NaN            NaN  API limit exceeded  440.0
#
# [300 rows x 7 columns]

# %%
with open('file5.json', 'r') as file:
    data = json.load(file)

# %%
flattened_data5 = []
for i in range(len(data)):
  keys = data[i].keys()
  if 'restaurants' in keys:
    restaurants = data[i]['restaurants']  

    for item in restaurants:
        restaurant = item['restaurant']
        flattened_data5.append({
            "Restaurant ID": restaurant.get("R", {}).get("res_id"),
            "Restaurant Name": restaurant.get("name"),
            "Location": restaurant["location"].get("address"),
            "Cuisine": restaurant.get("cuisines"),
            "Ratings": restaurant["user_rating"].get("aggregate_rating"),
            "Rating text": restaurant["user_rating"].get("rating_text"),
            "Average Cost for Two": restaurant.get("average_cost_for_two"),
            "Price Range": restaurant.get("price_range"),
            "Table Booking": restaurant.get("has_table_booking"),
            "Online Delivery": restaurant.get("has_online_delivery"),
            "Delivering now": restaurant.get("is_delivering_now"),
            "Longitude": restaurant["location"].get("longitude"),
            "Latitude": restaurant["location"].get("latitude"),
            "City": restaurant["location"].get("city"),
            "Locality": restaurant["location"].get("locality")
})

# %%
zomato_df5 = pd.DataFrame(flattened_data5)
zomato_df5
# Out:
#      Restaurant ID                Restaurant Name  \
# 0         17066603                       The Coop
# 1         17059541        Maggiano's Little Italy
# 2         17064405         Tako Cheena by Pom Pom
# 3         17057797     Bosphorous Turkish Cuisine
# 4         17057591    Bahama Breeze Island Grille
# ..             ...                            ...
# 415       17582627                  Senor Iguanas
# 416       17582625  Sandpiper Restaurant & Lounge
# 417       17582668                Texas Roadhouse
# 418       17582498                 Riverwalk Cafe
# 419       17582499                    Royal Hotel
#
#                                          Location  \
# 0    610 W Morse Boulevard, Winter Park, FL 32789
# 1      9101 International Drive,Orlando, FL 32819
# 2       932 North Mills Avenue, Orlando, FL 32803
# 3           108 S Park Ave, Winter Park, FL 32789
# 4     8849 International Drive, Orlando, FL 32819
# ..                                            ...
# 415            961 Hiline Rd, Pocatello, ID 83201
# 416            1400 Bench Rd, Pocatello, ID 83201
# 417       560 Bullock Street, Pocatello, ID 83202
# 418     695 E Main St, Lava Hot Springs, ID 83246
# 419      11 E Main St, Lava Hot Springs, ID 83246
#
#                                Cuisine Ratings Rating text  \
# 0           Southern, Cajun, Soul Food     3.6        Good
# 1                              Italian     4.4   Very Good
# 2    Asian, Latin American, Vegetarian     4.4   Very Good
# 3               Mediterranean, Turkish     4.2   Very Good
# 4                            Caribbean     4.3   Very Good
# ..                                 ...     ...         ...
# 415                            Mexican     3.6        Good
# 416           American, Seafood, Steak     3.6        Good
# 417               American, BBQ, Steak     3.5        Good
# 418                        Asian, Thai     3.6        Good
# 419                    Pizza, Bar Food     3.6        Good
#
#      Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                      25            2              0                0
# 1                      50            4              0                0
# 2                      10            1              0                0
# 3                      40            3              0                0
# 4                      45            3              0                0
# ..                    ...          ...            ...              ...
# 415                     0            1              0                0
# 416                    40            3              0                0
# 417                    45            3              0                0
# 418                    10            1              0                0
# 419                     0            1              0                0
#
#      Delivering now        Longitude       Latitude       City  \
# 0                 0   -81.3572190000  28.5973660000    Orlando
# 1                 0   -81.4714470000  28.4332350000    Orlando
# 2                 0   -81.3645470000  28.5578450000    Orlando
# 3                 0   -81.3508344000  28.5976271000    Orlando
# 4                 0   -81.4715260000  28.4370650000    Orlando
# ..              ...              ...            ...        ...
# 415               0  -112.4433000000  42.8942000000  Pocatello
# 416               0  -112.4320000000  42.9012000000  Pocatello
# 417               0  -112.4613260000  42.9105180000  Pocatello
# 418               0  -112.0132000000  42.6200000000  Pocatello
# 419               0  -112.0127000000  42.6192000000  Pocatello
#
#               Locality
# 0          Winter Park
# 1    I-Drive/Universal
# 2             Mills 50
# 3          Winter Park
# 4    I-Drive/Universal
# ..                 ...
# 415          Pocatello
# 416          Pocatello
# 417           Chubbuck
# 418   Lava Hot Springs
# 419   Lava Hot Springs
#
# [420 rows x 15 columns]

# %% [markdown]
# Datacleaning and preprocessing

# %%
zomato_df = pd.concat([zomato_df1,zomato_df2,zomato_df3,zomato_df4,zomato_df5])

# %%
zomato_df
# Out:
#      Restaurant ID                Restaurant Name  \
# 0           308322               Hauz Khas Social
# 1         18037817     Qubitos - The Terrace Cafe
# 2           312345                The Hudson Cafe
# 3           307490              Summer House Cafe
# 4         18241537                    38 Barracks
# ..             ...                            ...
# 415       17582627                  Senor Iguanas
# 416       17582625  Sandpiper Restaurant & Lounge
# 417       17582668                Texas Roadhouse
# 418       17582498                 Riverwalk Cafe
# 419       17582499                    Royal Hotel
#
#                                               Location  \
# 0               9-A & 12, Hauz Khas Village, New Delhi
# 1    C-7, Vishal Enclave, Opposite Metro Pillar 417...
# 2    2524, 1st Floor, Hudson Lane, Delhi University...
# 3    1st Floor, DDA Shopping Complex, Aurobindo Pla...
# 4       M-38, Outer Circle, Connaught Place, New Delhi
# ..                                                 ...
# 415                 961 Hiline Rd, Pocatello, ID 83201
# 416                 1400 Bench Rd, Pocatello, ID 83201
# 417            560 Bullock Street, Pocatello, ID 83202
# 418          695 E Main St, Lava Hot Springs, ID 83246
# 419           11 E Main St, Lava Hot Springs, ID 83246
#
#                                                Cuisine Ratings Rating text  \
# 0           Continental, American, Asian, North Indian     4.3   Very Good
# 1    Thai, European, Mexican, North Indian, Chinese...     4.5   Excellent
# 2                  Cafe, Italian, Continental, Chinese     4.4   Very Good
# 3                                 Italian, Continental     4.1   Very Good
# 4               North Indian, Italian, Asian, American     4.4   Very Good
# ..                                                 ...     ...         ...
# 415                                            Mexican     3.6        Good
# 416                           American, Seafood, Steak     3.6        Good
# 417                               American, BBQ, Steak     3.5        Good
# 418                                        Asian, Thai     3.6        Good
# 419                                    Pizza, Bar Food     3.6        Good
#
#      Average Cost for Two  Price Range  Table Booking  Online Delivery  \
# 0                    1600            3              1                1
# 1                    1500            3              1                0
# 2                     850            2              0                1
# 3                    1850            3              1                0
# 4                    1600            3              1                0
# ..                    ...          ...            ...              ...
# 415                     0            1              0                0
# 416                    40            3              0                0
# 417                    45            3              0                0
# 418                    10            1              0                0
# 419                     0            1              0                0
#
#      Delivering now        Longitude       Latitude       City  \
# 0                 0    77.1944706000  28.5542851000  New Delhi
# 1                 0    77.1177015000  28.6471325000  New Delhi
# 2                 0    77.2043172000  28.6949468000  New Delhi
# 3                 0    77.2038090000  28.5525204000  New Delhi
# 4                 0    77.2228584811  28.6330248887  New Delhi
# ..              ...              ...            ...        ...
# 415               0  -112.4433000000  42.8942000000  Pocatello
# 416               0  -112.4320000000  42.9012000000  Pocatello
# 417               0  -112.4613260000  42.9105180000  Pocatello
# 418               0  -112.0132000000  42.6200000000  Pocatello
# 419               0  -112.0127000000  42.6192000000  Pocatello
#
#                        Locality
# 0             Hauz Khas Village
# 1                Rajouri Garden
# 2    Delhi University-GTB Nagar
# 3                     Hauz Khas
# 4               Connaught Place
# ..                          ...
# 415                   Pocatello
# 416                   Pocatello
# 417                    Chubbuck
# 418            Lava Hot Springs
# 419            Lava Hot Springs
#
# [29753 rows x 15 columns]

# %%
zomato_df.shape
# Out:
# (29753, 15)

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29753 entries, 0 to 419
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         29753 non-null  int64
#  1   Restaurant Name       29753 non-null  object
#  2   Location              29753 non-null  object
#  3   Cuisine               29753 non-null  object
#  4   Ratings               29753 non-null  object
#  5   Rating text           29753 non-null  object
#  6   Average Cost for Two  29753 non-null  int64
#  7   Price Range           29753 non-null  int64
#  8   Table Booking         29753 non-null  int64
#  9   Online Delivery       29753 non-null  int64
#  10  Delivering now        29753 non-null  int64
#  11  Longitude             29753 non-null  object
#  12  Latitude              29753 non-null  object
#  13  City                  29753 non-null  object
#  14  Locality              29753 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.6+ MB

# %%
zomato_df['Ratings'] = pd.to_numeric(zomato_df['Ratings'], errors='coerce')
zomato_df['Ratings'] = pd.to_numeric(zomato_df['Ratings'], errors='coerce')
zomato_df['Longitude'] = pd.to_numeric(zomato_df['Longitude'], errors='coerce')
zomato_df['Latitude'] = pd.to_numeric(zomato_df['Latitude'], errors='coerce')

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29753 entries, 0 to 419
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         29753 non-null  int64
#  1   Restaurant Name       29753 non-null  object
#  2   Location              29753 non-null  object
#  3   Cuisine               29753 non-null  object
#  4   Ratings               29753 non-null  float64
#  5   Rating text           29753 non-null  object
#  6   Average Cost for Two  29753 non-null  int64
#  7   Price Range           29753 non-null  int64
#  8   Table Booking         29753 non-null  int64
#  9   Online Delivery       29753 non-null  int64
#  10  Delivering now        29753 non-null  int64
#  11  Longitude             29753 non-null  float64
#  12  Latitude              29753 non-null  float64
#  13  City                  29753 non-null  object
#  14  Locality              29753 non-null  object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 3.6+ MB

# %%
zomato_df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Location                0
# Cuisine                 0
# Ratings                 0
# Rating text             0
# Average Cost for Two    0
# Price Range             0
# Table Booking           0
# Online Delivery         0
# Delivering now          0
# Longitude               0
# Latitude                0
# City                    0
# Locality                0
# dtype: int64

# %%
zomato_df.describe()
# Out:
#        Restaurant ID       Ratings  Average Cost for Two   Price Range  \
# count   2.975300e+04  29753.000000           29753.00000  29753.000000
# mean    1.035475e+07      3.325201            2544.60888      2.183444
# std     8.534506e+06      1.270941           18230.51240      0.954264
# min     4.000000e+00      0.000000               0.00000      1.000000
# 25%     3.064070e+05      3.100000              50.00000      1.000000
# 50%     1.660886e+07      3.700000             450.00000      2.000000
# 75%     1.824528e+07      4.100000            1000.00000      3.000000
# max     1.850065e+07      4.900000          800000.00000      4.000000
#
#        Table Booking  Online Delivery  Delivering now     Longitude  \
# count   29753.000000     29753.000000    29753.000000  29753.000000
# mean        0.144221         0.192115        0.001949     63.466626
# std         0.351319         0.393970        0.044110     68.264524
# min         0.000000         0.000000        0.000000   -157.948486
# 25%         0.000000         0.000000        0.000000     77.088328
# 50%         0.000000         0.000000        0.000000     77.219739
# 75%         0.000000         0.000000        0.000000     77.363084
# max         1.000000         1.000000        1.000000    174.832089
#
#            Latitude
# count  29753.000000
# mean      19.114803
# std       23.496187
# min      -41.330428
# 25%       23.044337
# 50%       28.567720
# 75%       28.642216
# max       73.990000

# %%
zomato_df.to_csv('zomato_df.csv',index=False)
